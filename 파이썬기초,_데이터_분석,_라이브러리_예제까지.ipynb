# %%
# 변수 응용

s1 = "python"

s1 = s1 + "3"

# %%
s1 * 3
# Out:
# 'python3python3python3'

# %%
# 변수 아는 법

dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_4',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i2',
#  '_i3',
#  '_i4',
#  '_i5',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit',
#  's1']

# %%
globals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# 변수 응용\n\ns1 = "python"\n\ns1 = s1 + 3',
#   '# 변수 응용\n\ns1 = "python"\n\ns1 = s1 + 3',
#   '# 변수 응용\n\ns1 = "python"\n\ns1 = s1 + "3"',
#   's1 * 3',
#   '# 변수 아는 법\n\ndir()',
#   'globals()'],
#  '_oh': {4: 'python3python3python3',
#   5: ['In',
#    'Out',
#    '_',
#    '_4',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit',
#    's1']},
#  '_dh': ['/content'],
#  'In': ['',
# ...

# %%
locals()
# Out:
# {'__name__': '__main__',
#  '__doc__': 'Automatically created module for IPython interactive environment',
#  '__package__': None,
#  '__loader__': None,
#  '__spec__': None,
#  '__builtin__': <module 'builtins' (built-in)>,
#  '__builtins__': <module 'builtins' (built-in)>,
#  '_ih': ['',
#   '# 변수 응용\n\ns1 = "python"\n\ns1 = s1 + 3',
#   '# 변수 응용\n\ns1 = "python"\n\ns1 = s1 + 3',
#   '# 변수 응용\n\ns1 = "python"\n\ns1 = s1 + "3"',
#   's1 * 3',
#   '# 변수 아는 법\n\ndir()',
#   'globals()',
#   'locals()'],
#  '_oh': {4: 'python3python3python3',
#   5: ['In',
#    'Out',
#    '_',
#    '_4',
#    '__',
#    '___',
#    '__builtin__',
#    '__builtins__',
#    '__doc__',
#    '__loader__',
#    '__name__',
#    '__package__',
#    '__spec__',
#    '_dh',
#    '_i',
#    '_i1',
#    '_i2',
#    '_i3',
#    '_i4',
#    '_i5',
#    '_ih',
#    '_ii',
#    '_iii',
#    '_oh',
#    'exit',
#    'get_ipython',
#    'quit',
#    's1'],
#   6: {...}},
#  '_dh': ['/content'],
#  'In': ['',
# ...

# %%
# 변수 지우기
del 변수
